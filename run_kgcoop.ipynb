# %% [markdown]
# "# 2SFS + KgCoOp 통합 모듈 실행 파이프라인"

# %% [markdown]
# "## 1. 빠른 테스트 (Sanity Check)\n",
#         "에러 없이 모델이 초기화되고 Forward/Backward Pass(Loss 연산 등)가 정상적으로 흐르는지 확인하기 위해 **초소형 세팅**으로 실행합니다.\n",
#         "* `--shots 1`: 데이터 수를 최소화합니다.\n",
#         "* `--steps_per_shot 5`: 학습 스텝(iteration)을 5번만 진행하여 1~2분 안에 종료되도록 합니다."

# %%
"!uv run python -u train_2sfs.py \\\n",
        "    --dataset dtd \\\n",
        "    --shots 1 \\\n",
        "    --peft kgcoop \\\n",
        "    --n_ctx 8 \\\n",
        "    --setting base2new \\\n",
        "    --steps_per_shot 5"
