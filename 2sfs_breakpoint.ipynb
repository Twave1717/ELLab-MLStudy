# %% [markdown]
# # 2SFS Stage 1 breakpoint sweep

# %%
# %%bash
# mkdir -p logs/2sfs_breakpoint
#
# nohup setsid bash -c '
# uv run python -u train_2sfs.py --dataset eurosat --shots 1 --stage_one_ratio 1.0 --setting base2new > logs/2sfs_breakpoint/eurosat-ln-1shot.log 2>&1
# uv run python -u train_2sfs.py --dataset eurosat --shots 4 --stage_one_ratio 1.0 --setting base2new > logs/2sfs_breakpoint/eurosat-ln-4shot.log 2>&1
# uv run python -u train_2sfs.py --dataset eurosat --shots 8 --stage_one_ratio 1.0 --setting base2new > logs/2sfs_breakpoint/eurosat-ln-8shot.log 2>&1
# uv run python -u train_2sfs.py --dataset eurosat --shots 16 --stage_one_ratio 1.0 --setting base2new > logs/2sfs_breakpoint/eurosat-ln-16shot.log 2>&1
# uv run python -u train_2sfs.py --dataset eurosat --shots 2 --stage_one_ratio 1.0 --setting base2new > logs/2sfs_breakpoint/eurosat-ln-2shot.log 2>&1
# ' > logs/2sfs_breakpoint/eurosat-ln-queue.log 2>&1 < /dev/null &
# echo $! > logs/2sfs_breakpoint/eurosat-ln.pid
#
# nohup setsid bash -c '
# uv run python -u train_2sfs.py --dataset eurosat --shots 2 --peft lora --stage_one_ratio 1.0 --setting base2new > logs/2sfs_breakpoint/eurosat-lora-2shot.log 2>&1
# uv run python -u train_2sfs.py --dataset eurosat --shots 8 --peft lora --stage_one_ratio 1.0 --setting base2new > logs/2sfs_breakpoint/eurosat-lora-8shot.log 2>&1
# uv run python -u train_2sfs.py --dataset eurosat --shots 16 --peft lora --stage_one_ratio 1.0 --setting base2new > logs/2sfs_breakpoint/eurosat-lora-16shot.log 2>&1
# uv run python -u train_2sfs.py --dataset eurosat --shots 4 --peft lora --stage_one_ratio 1.0 --setting base2new > logs/2sfs_breakpoint/eurosat-lora-4shot.log 2>&1
# uv run python -u train_2sfs.py --dataset eurosat --shots 1 --peft lora --stage_one_ratio 1.0 --setting base2new > logs/2sfs_breakpoint/eurosat-lora-1shot.log 2>&1
# ' > logs/2sfs_breakpoint/eurosat-lora-queue.log 2>&1 < /dev/null &
# echo $! > logs/2sfs_breakpoint/eurosat-lora.pid
#
# nohup setsid bash -c '
# uv run python -u train_2sfs.py --dataset food101 --shots 4 --stage_one_ratio 1.0 --setting base2new > logs/2sfs_breakpoint/food101-ln-4shot.log 2>&1
# uv run python -u train_2sfs.py --dataset food101 --shots 16 --stage_one_ratio 1.0 --setting base2new > logs/2sfs_breakpoint/food101-ln-16shot.log 2>&1
# uv run python -u train_2sfs.py --dataset food101 --shots 2 --stage_one_ratio 1.0 --setting base2new > logs/2sfs_breakpoint/food101-ln-2shot.log 2>&1
# uv run python -u train_2sfs.py --dataset food101 --shots 1 --stage_one_ratio 1.0 --setting base2new > logs/2sfs_breakpoint/food101-ln-1shot.log 2>&1
# uv run python -u train_2sfs.py --dataset food101 --shots 8 --stage_one_ratio 1.0 --setting base2new > logs/2sfs_breakpoint/food101-ln-8shot.log 2>&1
# ' > logs/2sfs_breakpoint/food101-ln-queue.log 2>&1 < /dev/null &
# echo $! > logs/2sfs_breakpoint/food101-ln.pid
#
# nohup setsid bash -c '
# uv run python -u train_2sfs.py --dataset food101 --shots 8 --peft lora --stage_one_ratio 1.0 --setting base2new > logs/2sfs_breakpoint/food101-lora-8shot.log 2>&1
# uv run python -u train_2sfs.py --dataset food101 --shots 2 --peft lora --stage_one_ratio 1.0 --setting base2new > logs/2sfs_breakpoint/food101-lora-2shot.log 2>&1
# uv run python -u train_2sfs.py --dataset food101 --shots 1 --peft lora --stage_one_ratio 1.0 --setting base2new > logs/2sfs_breakpoint/food101-lora-1shot.log 2>&1
# uv run python -u train_2sfs.py --dataset food101 --shots 4 --peft lora --stage_one_ratio 1.0 --setting base2new > logs/2sfs_breakpoint/food101-lora-4shot.log 2>&1
# uv run python -u train_2sfs.py --dataset food101 --shots 16 --peft lora --stage_one_ratio 1.0 --setting base2new > logs/2sfs_breakpoint/food101-lora-16shot.log 2>&1
# ' > logs/2sfs_breakpoint/food101-lora-queue.log 2>&1 < /dev/null &
# echo $! > logs/2sfs_breakpoint/food101-lora.pid
#
# cat logs/2sfs_breakpoint/*.pid
# Out:
# 713846
# 713847
# 713848
# 713849

# %%
# !grep -H -E "^(Validation|Test)" logs/2sfs_breakpoint/*.log

# %%
# %load_ext tensorboard
# %tensorboard --logdir runs/2sfs
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# ERROR: Failed to launch TensorBoard (exited with 1).
# Contents of stderr:
# Traceback (most recent call last):
#   File "/usr/local/bin/tensorboard", line 5, in <module>
#     from tensorboard.main import run_main
# ModuleNotFoundError: No module named 'tensorboard'
